# %% [markdown]
# ##Optimizations to Quadratic Sieve for Prime Factorization

# %% [markdown]
# ### references:
# https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.26.6924&rep=rep1&type=pdf  (20-26, SIQS)
#
# https://maths-people.anu.edu.au/~brent/pd/rpb051i.pdf  (Brent-Pollard factorization)
#
# https://github.com/skollmann/PyFactorise/blob/master/factorise.py (multiple polynomial quadratic sieve)
#
#
# https://github.com/brendongo/factoring/blob/master/quadraticsieve.py

# %%
#!/usr/bin/python3 -O

from math import sqrt, log2, ceil, floor, gcd
import random
import sys
from builtins import ValueError


# Some tuning parameters
MAX_DIGITS_POLLARD = 30
POLLARD_QUICK_ITERATIONS = 20
MIN_DIGITS_POLLARD_QUICK2 = 45
POLLARD_QUICK2_ITERATIONS = 25
SIQS_TRIAL_DIVISION_EPS = 25
SIQS_MIN_PRIME_POLYNOMIAL = 400
SIQS_MAX_PRIME_POLYNOMIAL = 4000

# Number of iterations for the Miller-Rabin primality test
MILLER_RABIN_ITERATIONS = 50

# %%
class Polynomial:
    """A polynomial used for the Self-Initializing Quadratic Sieve."""

    def __init__(self, coeff=[], a=None, b=None):
        self.coeff = coeff
        self.a = a
        self.b = b

    def eval(self, x):
        res = 0
        for a in self.coeff[::-1]:
            res *= x
            res += a
        return res

# %%
class FactorBasePrime:
    """A factor base prime for the Self-Initializing Quadratic Sieve."""

    def __init__(self, p, tmem, lp):
        self.p = p
        self.soln1 = None
        self.soln2 = None
        self.tmem = tmem
        self.lp = lp
        self.ainv = None

# %%
def lowest_set_bit(a):
    b = (a & -a)
    low_bit = -1
    while (b):
        b >>= 1
        low_bit += 1
    return low_bit


def to_bits(k):
    """Return a generator that returns the bits of k, starting from the
    least significant bit, using True for 1s, and False for 0s.
    """
    k_binary = bin(k)[2:]
    return (bit == '1' for bit in k_binary[::-1])


def pow_mod(a, k, m):
    """Return a^k mod m."""
    r = 1
    b = a
    for bit in to_bits(k):
        if bit:
            r = (r * b) % m
        b = (b * b) % m
    return r


def is_quadratic_residue(a, p):
    """Return whether a is a quadratic residue modulo a prime p."""
    return legendre(a, (p - 1) // 2, 1, p) == 1


def legendre(a, q, l, n):
    x = q ** l
    if x == 0:
        return 1

    z = 1
    a %= n

    while x != 0:
        if x % 2 == 0:
            a = (a ** 2) % n
            x //= 2
        else:
            x -= 1
            z = (z * a) % n
    return z


def sqrt_mod_prime(a, p):
    """Return the square root of a modulo the prime p. Behaviour is
    undefined if a is not a quadratic residue mod p."""
    # Algorithm from http://www.mersennewiki.org/index.php/Modular_Square_Root
    assert a < p
    assert is_probable_prime(p)
    if a == 0:
        return 0
    if p == 2:
        return a
    if p % 2 == 0:
        return None
    p_mod_8 = p % 8
    if p_mod_8 == 1:
        # Shanks method
        q = p // 8
        e = 3
        while q % 2 == 0:
            q //= 2
            e += 1
        while True:
            x = random.randint(2, p - 1)
            z = pow_mod(x, q, p)
            if pow_mod(z, 2 ** (e - 1), p) != 1:
                break
        y = z
        r = e
        x = pow_mod(a, (q - 1) // 2, p)
        v = (a * x) % p
        w = (v * x) % p
        while True:
            if w == 1:
                return v
            k = 1
            while pow_mod(w, 2 ** k, p) != 1:
                k += 1
            d = pow_mod(y, 2 ** (r - k - 1), p)
            y = (d ** 2) % p
            r = k
            v = (d * v) % p
            w = (w * y) % p
    elif p_mod_8 == 5:
        v = pow_mod(2 * a, (p - 5) // 8, p)
        i = (2 * a * v * v) % p
        return (a * v * (i - 1)) % p
    else:
        return pow_mod(a, (p + 1) // 4, p)


def inv_mod(a, m):
    """Return the modular inverse of a mod m."""
    return eea(a, m)[0] % m


def eea(a, b):
    """Solve the equation a*x + b*y = gcd(a,b).
    Return (x, y, +/-gcd(a,b)).
    """
    if a == 0:
        return (0, 1, b)
    x = eea(b % a, a)
    return (x[1] - b // a * x[0], x[0], x[2])


def is_probable_prime(a):
    """Perform the mi test to determine whether the
    given number a is a prime. Return True if the number is a prime
    with very high probability, and False if it is definitely composite.
    """
    if a == 2:
        return True
    if a == 1 or a % 2 == 0:
        return False
    return primality_test_miller_rabin(a, MILLER_RABIN_ITERATIONS)


def primality_test_miller_rabin(a, iterations):
    m = a - 1
    lb = lowest_set_bit(m)
    m >>= lb

    for _ in range(iterations):
        b = random.randint(2, a - 1)
        j = 0
        z = pow_mod(b, m, a)
        while not ((j == 0 and z == 1) or z == a - 1):
            if (j > 0 and z == 1 or j + 1 == lb):
                return False
            j += 1
            z = (z * z) % a

    return True


def siqs_factor_base_primes(n, nf):
    """Compute and return nf factor base primes suitable for a Quadratic
    Sieve on the number n.
    """
    global small_primes
    factor_base = []
    for p in small_primes:
        if is_quadratic_residue(n, p):
            t = sqrt_mod_prime(n % p, p)
            lp = round(log2(p))
            factor_base.append(FactorBasePrime(p, t, lp))
            if len(factor_base) >= nf:
                break
    return factor_base


def siqs_find_first_poly(n, m, factor_base):
    """Compute the first of a set of polynomials for the Self-
    Initialising Quadratic Sieve.
    """
    p_min_i = None
    p_max_i = None
    for i, fb in enumerate(factor_base):
        if p_min_i is None and fb.p >= SIQS_MIN_PRIME_POLYNOMIAL:
            p_min_i = i
        if p_max_i is None and fb.p > SIQS_MAX_PRIME_POLYNOMIAL:
            p_max_i = i - 1
            break

    # The following may happen if the factor base is small, make sure
    # that we have enough primes.
    if p_max_i is None:
        p_max_i = len(factor_base) - 1
    if p_min_i is None or p_max_i - p_min_i < 20:
        p_min_i = min(p_min_i, 5)

    target = sqrt(2 * float(n)) / m
    target1 = target / ((factor_base[p_min_i].p + 
                         factor_base[p_max_i].p) / 2) ** 0.5

    # find q such that the product of factor_base[q_i] is approximately
    # sqrt(2 * n) / m; try a few different sets to find a good one
    best_q, best_a, best_ratio = None, None, None
    for _ in range(30): 
        a = 1
        q = []

        while a < target1:
            p_i = 0
            while p_i == 0 or p_i in q:
                p_i = random.randint(p_min_i, p_max_i)
            p = factor_base[p_i].p
            a *= p
            q.append(p_i)

        ratio = a / target

        # ratio too small seems to be not good
        if (best_ratio is None or (ratio >= 0.9 and ratio < best_ratio) or
                    best_ratio < 0.9 and ratio > best_ratio):
            best_q = q
            best_a = a
            best_ratio = ratio
    a = best_a
    q = best_q

    s = len(q)
    B = []
    for l in range(s):
        fb_l = factor_base[q[l]]
        q_l = fb_l.p
        assert a % q_l == 0
        gamma = (fb_l.tmem * inv_mod(a // q_l, q_l)) % q_l
        if gamma > q_l // 2:
            gamma = q_l - gamma
        B.append(a // q_l * gamma)

    b = sum(B) % a
    b_orig = b
    if (2 * b > a):
        b = a - b

    assert 0 < b
    assert 2 * b <= a
    assert ((b * b - n) % a == 0)

    g = Polynomial([b * b - n, 2 * a * b, a * a], a, b_orig)
    h = Polynomial([b, a])
    for fb in factor_base:
        if a % fb.p != 0:
            fb.ainv = inv_mod(a, fb.p)
            fb.soln1 = (fb.ainv * (fb.tmem - b)) % fb.p
            fb.soln2 = (fb.ainv * (-fb.tmem - b)) % fb.p

    return g, h, B


def siqs_find_next_poly(n, factor_base, i, g, B):
    """Compute the (i+1)-th polynomials for the Self-Initialising
    Quadratic Sieve, given that g is the i-th polynomial.
    """
    v = lowest_set_bit(i) + 1
    z = -1 if ceil(i / (2 ** v)) % 2 == 1 else 1
    b = (g.b + 2 * z * B[v - 1]) % g.a
    a = g.a
    b_orig = b
    if (2 * b > a):
        b = a - b
    assert ((b * b - n) % a == 0)

    g = Polynomial([b * b - n, 2 * a * b, a * a], a, b_orig)
    h = Polynomial([b, a])
    for fb in factor_base:
        if a % fb.p != 0:
            fb.soln1 = (fb.ainv * (fb.tmem - b)) % fb.p
            fb.soln2 = (fb.ainv * (-fb.tmem - b)) % fb.p

    return g, h


def siqs_sieve(factor_base, m):
    """Perform the sieving step of the SIQS. Return the sieve array."""
    sieve_array = [0] * (2 * m + 1)
    for fb in factor_base:
        if fb.soln1 is None:
            continue
        p = fb.p
        i_start_1 = -((m + fb.soln1) // p)
        a_start_1 = fb.soln1 + i_start_1 * p
        lp = fb.lp
        if p > 20:
            for a in range(a_start_1 + m, 2 * m + 1, p):
                sieve_array[a] += lp

            i_start_2 = -((m + fb.soln2) // p)
            a_start_2 = fb.soln2 + i_start_2 * p
            for a in range(a_start_2 + m, 2 * m + 1, p):
                sieve_array[a] += lp
    return sieve_array


def siqs_trial_divide(a, factor_base):
    """Determine whether the given number a can be fully factorised into
    primes from the factors base. If so, return the indices of the
    factors from the factor base. If not, return None.
    """
    divisors_idx = []
    for i, fb in enumerate(factor_base):
        if a % fb.p == 0:
            exp = 0
            while a % fb.p == 0:
                a //= fb.p
                exp += 1
            divisors_idx.append((i, exp))
        if a == 1:
            return divisors_idx
    return None


def siqs_trial_division(n, sieve_array, factor_base, smooth_relations, g, h, m,
                        req_relations):
    """Perform the trial division step of the Self-Initializing
    Quadratic Sieve.
    """
    sqrt_n = sqrt(float(n))
    limit = log2(m * sqrt_n) - SIQS_TRIAL_DIVISION_EPS
    for (i, sa) in enumerate(sieve_array):
        if sa >= limit:
            x = i - m
            gx = g.eval(x)
            divisors_idx = siqs_trial_divide(gx, factor_base)
            if divisors_idx is not None:
                u = h.eval(x)
                v = gx
                assert (u * u) % n == v % n
                smooth_relations.append((u, v, divisors_idx))
                if (len(smooth_relations) >= req_relations):
                    return True
    return False


def siqs_build_matrix(factor_base, smooth_relations):
    """Build the matrix for the linear algebra step of the Quadratic Sieve."""
    fb = len(factor_base)
    M = []
    for sr in smooth_relations:
        mi = [0] * fb
        for j, exp in sr[2]:
            mi[j] = exp % 2
        M.append(mi)
    return M


def siqs_build_matrix_opt(M):
    """Convert the given matrix M of 0s and 1s into a list of numbers m
    that correspond to the columns of the matrix.
    The j-th number encodes the j-th column of matrix M in binary:
    The i-th bit of m[i] is equal to M[i][j].
    """
    m = len(M[0])
    cols_binary = [""] * m
    for mi in M:
        for j, mij in enumerate(mi):
            cols_binary[j] += "1" if mij else "0"
    return [int(cols_bin[::-1], 2) for cols_bin in cols_binary], len(M), m


def add_column_opt(M_opt, tgt, src):
    """For a matrix produced by siqs_build_matrix_opt, add the column
    src to the column target (mod 2).
    """
    M_opt[tgt] ^= M_opt[src]


def find_pivot_column_opt(M_opt, j):
    """For a matrix produced by siqs_build_matrix_opt, return the row of
    the first non-zero entry in column j, or None if no such row exists.
    """
    if M_opt[j] == 0:
        return None
    return lowest_set_bit(M_opt[j])


def siqs_solve_matrix_opt(M_opt, n, m):
    """
    Perform the linear algebra step of the SIQS. Perform fast
    Gaussian elimination to determine pairs of perfect squares mod n.
    Use the optimisations described in [1].
    [1] Koç, Çetin K., and Sarath N. Arachchige. 'A Fast Algorithm for
        Gaussian Elimination over GF (2) and its Implementation on the
        GAPP.' Journal of Parallel and Distributed Computing 13.1
        (1991): 118-122.
    """
    row_is_marked = [False] * n
    pivots = [-1] * m
    for j in range(m):
        i = find_pivot_column_opt(M_opt, j)
        if i is not None:
            pivots[j] = i
            row_is_marked[i] = True
            for k in range(m):
                if k != j and (M_opt[k] >> i) & 1:  # test M[i][k] == 1
                    add_column_opt(M_opt, k, j)
    perf_squares = []
    for i in range(n):
        if not row_is_marked[i]:
            perfect_sq_indices = [i]
            for j in range(m):
                if (M_opt[j] >> i) & 1:  # test M[i][j] == 1
                    perfect_sq_indices.append(pivots[j])
            perf_squares.append(perfect_sq_indices)
    return perf_squares


def siqs_calc_sqrts(square_indices, smooth_relations):
    """Given on of the solutions returned by siqs_solve_matrix_opt and
    the corresponding smooth relations, calculate the pair [a, b], such
    that a^2 = b^2 (mod n).
    """
    res = [1, 1]
    for idx in square_indices:
        res[0] *= smooth_relations[idx][0]
        res[1] *= smooth_relations[idx][1]
    res[1] = sqrt_int(res[1])
    return res


def sqrt_int(n):
    """Return the square root of the given integer, rounded down to the
    nearest integer.
    """
    a = n
    s = 0
    o = 1 << (floor(log2(n)) & ~1)
    while o != 0:
        t = s + o
        if a >= t:
            a -= t
            s = (s >> 1) + o
        else:
            s >>= 1
        o >>= 2
    assert s * s == n
    return s


def kth_root_int(n, k):
    """Return the k-th root of the given integer n, rounded down to the
    nearest integer.
    """
    u = n
    s = n + 1
    while u < s:
        s = u
        t = (k - 1) * s + n // pow(s, k - 1)
        u = t // k
    return s


def siqs_factor_from_square(n, square_indices, smooth_relations):
    """Given one of the solutions returned by siqs_solve_matrix_opt,
    return the factor f determined by f = gcd(a - b, n), where
    a, b are calculated from the solution such that a*a = b*b (mod n).
    Return f, a factor of n (possibly a trivial one).
    """
    sqrt1, sqrt2 = siqs_calc_sqrts(square_indices, smooth_relations)
    assert (sqrt1 * sqrt1) % n == (sqrt2 * sqrt2) % n
    return gcd(abs(sqrt1 - sqrt2), n)


def siqs_find_factors(n, perfect_squares, smooth_relations):
    """Perform the last step of the Self-Initialising Quadratic Field.
    Given the solutions returned by siqs_solve_matrix_opt, attempt to
    identify a number of (not necessarily prime) factors of n, and
    return them.
    """
    factors = []
    rem = n
    non_prime_factors = set()
    prime_factors = set()
    for square_indices in perfect_squares:
        fact = siqs_factor_from_square(n, square_indices, smooth_relations)
        if fact != 1 and fact != rem:
            if is_probable_prime(fact):
                if fact not in prime_factors:
                    print ("SIQS: Prime factor found: %d" % fact)
                    prime_factors.add(fact)

                while rem % fact == 0:
                    factors.append(fact)
                    rem //= fact

                if rem == 1:
                    break
                if is_probable_prime(rem):
                    factors.append(rem)
                    rem = 1
                    break
            else:
                if fact not in non_prime_factors:
                    print ("SIQS: Non-prime factor found: %d" % fact)
                    non_prime_factors.add(fact)

    if rem != 1 and non_prime_factors:
        non_prime_factors.add(rem)
        for fact in sorted(siqs_find_more_factors_gcd(non_prime_factors)):
            while fact != 1 and rem % fact == 0:
                print ("SIQS: Prime factor found: %d" % fact)
                factors.append(fact)
                rem //= fact
            if rem == 1 or is_probable_prime(rem):
                break

    if rem != 1:
        factors.append(rem)
    return factors


def siqs_find_more_factors_gcd(numbers):
    res = set()
    for n in numbers:
        res.add(n)
        for m in numbers:
            if n != m:
                fact = gcd(n, m)
                if fact != 1 and fact != n and fact != m:
                    if fact not in res:
                        print("SIQS: GCD found non-trivial factor: %d" % fact)
                        res.add(fact)
                    res.add(n // fact)
                    res.add(m // fact)
    return res


def siqs_choose_nf_m(d):
    """Choose parameters nf (sieve of factor base) and m (for sieving
    in [-m,m].
    """
    # Using similar parameters as msieve-1.52
    if d <= 34:
        return 200, 65536
    if d <= 36:
        return 300, 65536
    if d <= 38:
        return 400, 65536
    if d <= 40:
        return 500, 65536
    if d <= 42:
        return 600, 65536
    if d <= 44:
        return 700, 65536
    if d <= 48:
        return 1000, 65536
    if d <= 52:
        return 1200, 65536
    if d <= 56:
        return 2000, 65536 * 3
    if d <= 60:
        return 4000, 65536 * 3
    if d <= 66:
        return 6000, 65536 * 3
    if d <= 74:
        return 10000, 65536 * 3
    if d <= 80:
        return 30000, 65536 * 3
    if d <= 88:
        return 50000, 65536 * 3
    if d <= 94:
        return 60000, 65536 * 9
    return 100000, 65536 * 9


def siqs_factorise(n):
    """Use the Self-Initializing Quadratic Sieve algorithm to identify
    one or more non-trivial factors of the given number n. Return the
    factors as a list.
    """
    dig = len(str(n))
    nf, m = siqs_choose_nf_m(dig)

    factor_base = siqs_factor_base_primes(n, nf)

    required_relations_ratio = 1.05
    success = False
    smooth_relations = []
    prev_cnt = 0
    i_poly = 0
    while not success:
        print("*** Step 1/2: Finding smooth relations ***")
        required_relations = round(len(factor_base) * required_relations_ratio)
        print("Target: %d relations" % required_relations)
        enough_relations = False
        while not enough_relations:
            if i_poly == 0:
                g, h, B = siqs_find_first_poly(n, m, factor_base)
            else:
                g, h = siqs_find_next_poly(n, factor_base, i_poly, g, B)
            i_poly += 1
            if i_poly >= 2 ** (len(B) - 1):
                i_poly = 0
            sieve_array = siqs_sieve(factor_base, m)
            enough_relations = siqs_trial_division(
                n, sieve_array, factor_base, smooth_relations,
                g, h, m, required_relations)

            if (len(smooth_relations) >= required_relations or
                i_poly % 8 == 0 and len(smooth_relations) > prev_cnt):
                print("Total %d/%d relations." %
                      (len(smooth_relations), required_relations))
                prev_cnt = len(smooth_relations)

        print("*** Step 2/2: Linear Algebra ***")
        print("Building matrix for linear algebra step...")
        M = siqs_build_matrix(factor_base, smooth_relations)
        M_opt, M_n, M_m = siqs_build_matrix_opt(M)

        print("Finding perfect squares using matrix...")
        perfect_squares = siqs_solve_matrix_opt(M_opt, M_n, M_m)

        print("Finding factors from perfect squares...")
        factors = siqs_find_factors(n, perfect_squares, smooth_relations)
        if len(factors) > 1:
            success = True
        else:
            print("Failed to find a solution. Finding more relations...")
            required_relations_ratio += 0.05

    return factors


def check_factor(n, i, factors):
    while n % i == 0:
        n //= i
        factors.append(i)
        if is_probable_prime(n):
            factors.append(n)
            n = 1
    return n


def trial_div_init_primes(n, upper_bound):
    """Perform trial division on the given number n using all primes up
    to upper_bound. Initialise the global variable small_primes with a
    list of all primes <= upper_bound. Return (factors, rem), where
    factors is the list of identified prime factors of n, and rem is the
    remaining factor. If rem = 1, the function terminates early, without
    fully initialising small_primes.
    """
    print("Trial division and initialising small primes...")
    global small_primes
    is_prime = [True] * (upper_bound + 1)
    is_prime[0:2] = [False] * 2
    factors = []
    small_primes = []
    max_i = sqrt_int(upper_bound)
    rem = n
    for i in range(2, max_i + 1):
        if is_prime[i]:
            small_primes.append(i)
            rem = check_factor(rem, i, factors)
            if rem == 1:
                return factors, 1

            for j in (range(i ** 2, upper_bound + 1, i)):
                is_prime[j] = False

    for i in range(max_i + 1, upper_bound + 1):
        if is_prime[i]:
            small_primes.append(i)
            rem = check_factor(rem, i, factors)
            if rem == 1:
                return factors, 1

    print("Primes initialised.")
    return factors, rem


def pollard_brent_f(c, n, x):
    """Return f(x) = (x^2 + c)%n. Assume c < n.
    """
    x1 = (x * x) % n + c
    if x1 >= n:
        x1 -= n
    assert x1 >= 0 and x1 < n
    return x1


def pollard_brent_find_factor(n, max_iter=None):
    """Perform Brent's variant of the Pollard rho factorisation
    algorithm to attempt to a non-trivial factor of the given number n.
    If max_iter > 0, return None if no factors were found within
    max_iter iterations.
    """
    y, c, m = (random.randint(1, n - 1) for _ in range(3))
    r, q, g = 1, 1, 1
    i = 0
    while g == 1:
        x = y
        for _ in range(r):
            y = pollard_brent_f(c, n, y)
        k = 0
        while k < r and g == 1:
            ys = y
            for _ in range(min(m, r - k)):
                y = pollard_brent_f(c, n, y)
                q = (q * abs(x - y)) % n
            g = gcd(q, n)
            k += m
        r *= 2
        if max_iter:
            i += 1
            if (i == max_iter):
                return None

    if g == n:
        while True:
            ys = pollard_brent_f(c, n, ys)
            g = gcd(abs(x - ys), n)
            if g > 1:
                break
    return g


def pollard_brent_quick(n, factors):
    """Perform up to max_iter iterations of Brent's variant of the
    Pollard rho factorisation algorithm to attempt to find small
    prime factors. Restart the algorithm each time a factor was found.
    Add all identified prime factors to factors, and return 1 if all
    prime factors were found, or otherwise the remaining factor.
    """
    rem = n
    while True:
        if is_probable_prime(rem):
            factors.append(rem)
            rem = 1
            break

        digits = len(str(n))
        if digits < MIN_DIGITS_POLLARD_QUICK2:
            max_iter = POLLARD_QUICK_ITERATIONS
        else:
            max_iter = POLLARD_QUICK2_ITERATIONS

        f = pollard_brent_find_factor(rem, max_iter)
        if f and f < rem:
            if is_probable_prime(f):
                print("Pollard rho (Brent): Prime factor found: %s" % f)
                factors.append(f)
                assert rem % f == 0
                rem //= f
            else:
                print("Pollard rho (Brent): Non-prime factor found: %s" % f)
                rem_f = pollard_brent_quick(f, factors)
                rem = (rem // f) * rem_f
        else:
            print("No (more) small factors found.")
            break
    return rem


def check_perfect_power(n):
    """Check if the given integer is a perfect power. If yes, return
    (r, b) such that r^b == n. If no, return None. Assume that
    global small_primes has already been initialised and that n does
    not have any prime factors from small_primes.
    """
    largest_checked_prime = small_primes[-1]
    for b in small_primes:
        bth_root = kth_root_int(n, b)
        if bth_root < largest_checked_prime:
            break
        if (bth_root ** b == n):
            return (bth_root, b)
    return None


def find_prime_factors(n):
    """Return one or more prime factors of the given number n. Assume
    that n is not a prime and does not have very small factors, and that
    the global small_primes has already been initialised. Do not return
    duplicate factors.
    """

    print("Checking whether %d is a perfect power..." % n)
    perfect_power = check_perfect_power(n)
    if perfect_power:
        print("%d is %d^%d" % (n, perfect_power[0], perfect_power[1]))
        factors = [perfect_power[0]]
    else:
        print("Not a perfect power.")
        digits = len(str(n))
        if digits <= MAX_DIGITS_POLLARD:
            print("Using Pollard rho (Brent's variant) to factorise %d (%d digits)..."
                  % (n, digits))
            factors = [pollard_brent_find_factor(n)]
        else:
            print("Using Self-Initializing Quadratic Sieve to factorise" +
                  " %d (%d digits)..." % (n, digits))
            factors = siqs_factorise(n)

    prime_factors = []
    for f in set(factors):
        for pf in find_all_prime_factors(f):
            prime_factors.append(pf)

    return prime_factors


def find_all_prime_factors(n):
    """Return all prime factors of the given number n. Assume that n
    does not have very small factors and that the global small_primes
    has already been initialised.
    """
    rem = n
    factors = []

    while rem > 1:
        if is_probable_prime(rem):
            factors.append(rem)
            break

        for f in find_prime_factors(rem):
            print("Prime factor found: %d" % f)
            assert is_probable_prime(f)
            assert rem % f == 0
            while rem % f == 0:
                rem //= f
                factors.append(f)

    return factors


def product(factors):
    """Return the product of all numbers in the given list."""
    prod = 1
    for f in factors:
        prod *= f
    return prod


def factorise(n):
    """Factorise the given integer n >= 1 into its prime factors."""

    if type(n) != int or n < 1:
        raise ValueError("Number needs to be an integer >= 1")

    print("Factorising %d (%d digits)..." % (n, len(str(n))))
    if n == 1:
        return []

    if is_probable_prime(n):
        return [n]

    factors, rem = trial_div_init_primes(n, 1000000)

    if factors:
        print("Prime factors found so far: %s" % factors)
    else:
        print("No small factors found.")

    if rem != 1:
        digits = len(str(rem))
        if digits > MAX_DIGITS_POLLARD:
            print("Attempting quick Pollard rho (Brent's variant) to find slightly " +
                  "larger factors...")
            rem = pollard_brent_quick(rem, factors)
        if rem > 1:
            for fr in find_all_prime_factors(rem):
                factors.append(fr)

    factors.sort()
    assert product(factors) == n
    for p in factors:
        assert is_probable_prime(p)
    return factors

# %%
l = [16921456439215439701, 3744843080529615909019181510330554205500926021947, 6172835808641975203638304919691358469663, 46839566299936919234246726809]
for N in l:  
    print("\nSuccess. Prime factors: %s" % factorise(N))
# Out:
# Factorising 16921456439215439701 (20 digits)...
# Trial division and initialising small primes...
# Primes initialised.
# No small factors found.
# Checking whether 16921456439215439701 is a perfect power...
# Not a perfect power.
# Using Pollard rho (Brent's variant) to factorise 16921456439215439701 (20 digits)...
# Prime factor found: 5915587277
#
# Success. Prime factors: [2860486313, 5915587277]
# Factorising 3744843080529615909019181510330554205500926021947 (49 digits)...
# Trial division and initialising small primes...
# Primes initialised.
# No small factors found.
# Attempting quick Pollard rho (Brent's variant) to find slightly larger factors...
# No (more) small factors found.
# Checking whether 3744843080529615909019181510330554205500926021947 is a perfect power...
# Not a perfect power.
# Using Self-Initializing Quadratic Sieve to factorise 3744843080529615909019181510330554205500926021947 (49 digits)...
# *** Step 1/2: Finding smooth relations ***
# Target: 1260 relations
# Total 1/1260 relations.
# Total 2/1260 relations.
# Total 3/1260 relations.
# Total 4/1260 relations.
# Total 5/1260 relations.
# Total 6/1260 relations.
# Total 9/1260 relations.
# Total 10/1260 relations.
# Total 11/1260 relations.
# Total 12/1260 relations.
# Total 13/1260 relations.
# Total 14/1260 relations.
# Total 15/1260 relations.
# Total 16/1260 relations.
# Total 18/1260 relations.
# Total 19/1260 relations.
# Total 21/1260 relations.
# Total 22/1260 relations.
# Total 23/1260 relations.
# Total 24/1260 relations.
# Total 25/1260 relations.
# Total 26/1260 relations.
# Total 28/1260 relations.
# Total 29/1260 relations.
# Total 30/1260 relations.
# Total 31/1260 relations.
# Total 32/1260 relations.
# Total 33/1260 relations.
# Total 35/1260 relations.
# Total 36/1260 relations.
# Total 37/1260 relations.
# Total 38/1260 relations.
# Total 39/1260 relations.
# Total 40/1260 relations.
# Total 41/1260 relations.
# Total 42/1260 relations.
# Total 43/1260 relations.
# Total 44/1260 relations.
# Total 45/1260 relations.
# Total 46/1260 relations.
# Total 47/1260 relations.
# Total 48/1260 relations.
# Total 50/1260 relations.
# Total 51/1260 relations.
# Total 52/1260 relations.
# Total 53/1260 relations.
# Total 55/1260 relations.
# Total 57/1260 relations.
# Total 58/1260 relations.
# Total 60/1260 relations.
# Total 61/1260 relations.
# Total 62/1260 relations.
# Total 63/1260 relations.
# Total 64/1260 relations.
# Total 65/1260 relations.
# Total 66/1260 relations.
# Total 67/1260 relations.
# Total 68/1260 relations.
# Total 69/1260 relations.
# Total 70/1260 relations.
# Total 71/1260 relations.
# Total 72/1260 relations.
# Total 73/1260 relations.
# Total 75/1260 relations.
# Total 76/1260 relations.
# Total 77/1260 relations.
# Total 78/1260 relations.
# Total 79/1260 relations.
# Total 80/1260 relations.
# Total 81/1260 relations.
# Total 83/1260 relations.
# Total 84/1260 relations.
# Total 85/1260 relations.
# Total 87/1260 relations.
# Total 88/1260 relations.
# Total 89/1260 relations.
# Total 91/1260 relations.
# Total 92/1260 relations.
# Total 94/1260 relations.
# Total 95/1260 relations.
# Total 96/1260 relations.
# Total 98/1260 relations.
# Total 99/1260 relations.
# Total 101/1260 relations.
# Total 102/1260 relations.
# Total 103/1260 relations.
# Total 104/1260 relations.
# Total 105/1260 relations.
# Total 106/1260 relations.
# Total 107/1260 relations.
# Total 108/1260 relations.
# Total 109/1260 relations.
# Total 110/1260 relations.
# Total 111/1260 relations.
# Total 113/1260 relations.
# Total 114/1260 relations.
# Total 115/1260 relations.
# Total 117/1260 relations.
# Total 119/1260 relations.
# Total 121/1260 relations.
# Total 122/1260 relations.
# Total 123/1260 relations.
# Total 124/1260 relations.
# Total 125/1260 relations.
# Total 126/1260 relations.
# Total 127/1260 relations.
# Total 128/1260 relations.
# Total 129/1260 relations.
# Total 132/1260 relations.
# Total 133/1260 relations.
# Total 134/1260 relations.
# Total 135/1260 relations.
# Total 137/1260 relations.
# Total 139/1260 relations.
# Total 140/1260 relations.
# Total 141/1260 relations.
# Total 142/1260 relations.
# Total 143/1260 relations.
# Total 144/1260 relations.
# Total 145/1260 relations.
# Total 146/1260 relations.
# Total 147/1260 relations.
# Total 149/1260 relations.
# Total 150/1260 relations.
# Total 151/1260 relations.
# Total 153/1260 relations.
# Total 155/1260 relations.
# Total 156/1260 relations.
# Total 157/1260 relations.
# Total 158/1260 relations.
# Total 159/1260 relations.
# Total 160/1260 relations.
# Total 161/1260 relations.
# Total 162/1260 relations.
# Total 165/1260 relations.
# Total 166/1260 relations.
# Total 167/1260 relations.
# Total 169/1260 relations.
# Total 170/1260 relations.
# Total 171/1260 relations.
# Total 172/1260 relations.
# Total 173/1260 relations.
# Total 175/1260 relations.
# Total 176/1260 relations.
# Total 178/1260 relations.
# Total 179/1260 relations.
# Total 180/1260 relations.
# Total 182/1260 relations.
# Total 183/1260 relations.
# Total 184/1260 relations.
# Total 186/1260 relations.
# Total 187/1260 relations.
# Total 188/1260 relations.
# Total 189/1260 relations.
# Total 190/1260 relations.
# Total 191/1260 relations.
# Total 192/1260 relations.
# Total 193/1260 relations.
# Total 194/1260 relations.
# Total 195/1260 relations.
# Total 196/1260 relations.
# Total 197/1260 relations.
# Total 198/1260 relations.
# Total 199/1260 relations.
# Total 200/1260 relations.
# Total 201/1260 relations.
# Total 202/1260 relations.
# Total 203/1260 relations.
# Total 204/1260 relations.
# Total 205/1260 relations.
# Total 206/1260 relations.
# Total 208/1260 relations.
# Total 209/1260 relations.
# Total 211/1260 relations.
# Total 213/1260 relations.
# Total 214/1260 relations.
# Total 215/1260 relations.
# Total 216/1260 relations.
# Total 217/1260 relations.
# Total 221/1260 relations.
# Total 222/1260 relations.
# Total 223/1260 relations.
# Total 224/1260 relations.
# Total 225/1260 relations.
# Total 226/1260 relations.
# Total 227/1260 relations.
# Total 228/1260 relations.
# Total 229/1260 relations.
# Total 230/1260 relations.
# Total 231/1260 relations.
# Total 232/1260 relations.
# Total 233/1260 relations.
# Total 234/1260 relations.
# Total 235/1260 relations.
# Total 236/1260 relations.
# Total 237/1260 relations.
# Total 238/1260 relations.
# Total 239/1260 relations.
# Total 240/1260 relations.
# Total 241/1260 relations.
# Total 242/1260 relations.
# Total 243/1260 relations.
# Total 244/1260 relations.
# Total 245/1260 relations.
# Total 246/1260 relations.
# Total 247/1260 relations.
# Total 248/1260 relations.
# Total 249/1260 relations.
# Total 250/1260 relations.
# Total 251/1260 relations.
# Total 252/1260 relations.
# Total 253/1260 relations.
# Total 254/1260 relations.
# Total 255/1260 relations.
# Total 256/1260 relations.
# Total 257/1260 relations.
# Total 258/1260 relations.
# Total 259/1260 relations.
# Total 260/1260 relations.
# Total 262/1260 relations.
# Total 263/1260 relations.
# Total 264/1260 relations.
# Total 265/1260 relations.
# Total 266/1260 relations.
# Total 267/1260 relations.
# Total 268/1260 relations.
# Total 270/1260 relations.
# Total 271/1260 relations.
# Total 273/1260 relations.
# Total 274/1260 relations.
# Total 276/1260 relations.
# Total 277/1260 relations.
# Total 278/1260 relations.
# Total 279/1260 relations.
# Total 281/1260 relations.
# Total 282/1260 relations.
# Total 283/1260 relations.
# Total 284/1260 relations.
# Total 285/1260 relations.
# Total 286/1260 relations.
# Total 287/1260 relations.
# Total 288/1260 relations.
# Total 289/1260 relations.
# Total 290/1260 relations.
# Total 291/1260 relations.
# Total 292/1260 relations.
# Total 293/1260 relations.
# Total 294/1260 relations.
# Total 295/1260 relations.
# Total 296/1260 relations.
# Total 297/1260 relations.
# Total 298/1260 relations.
# Total 299/1260 relations.
# Total 300/1260 relations.
# Total 302/1260 relations.
# Total 303/1260 relations.
# Total 304/1260 relations.
# Total 305/1260 relations.
# Total 306/1260 relations.
# Total 307/1260 relations.
# Total 308/1260 relations.
# Total 309/1260 relations.
# Total 310/1260 relations.
# Total 312/1260 relations.
# Total 313/1260 relations.
# Total 314/1260 relations.
# Total 316/1260 relations.
# Total 318/1260 relations.
# Total 319/1260 relations.
# Total 320/1260 relations.
# Total 321/1260 relations.
# Total 322/1260 relations.
# Total 323/1260 relations.
# Total 324/1260 relations.
# Total 327/1260 relations.
# Total 328/1260 relations.
# Total 329/1260 relations.
# Total 330/1260 relations.
# Total 331/1260 relations.
# Total 332/1260 relations.
# Total 333/1260 relations.
# Total 334/1260 relations.
# Total 335/1260 relations.
# Total 336/1260 relations.
# Total 337/1260 relations.
# Total 338/1260 relations.
# Total 340/1260 relations.
# Total 342/1260 relations.
# Total 343/1260 relations.
# Total 344/1260 relations.
# Total 345/1260 relations.
# Total 346/1260 relations.
# Total 347/1260 relations.
# Total 348/1260 relations.
# Total 349/1260 relations.
# Total 350/1260 relations.
# Total 351/1260 relations.
# Total 352/1260 relations.
# Total 353/1260 relations.
# Total 354/1260 relations.
# Total 355/1260 relations.
# Total 356/1260 relations.
# Total 357/1260 relations.
# Total 360/1260 relations.
# Total 361/1260 relations.
# Total 362/1260 relations.
# Total 364/1260 relations.
# Total 365/1260 relations.
# Total 366/1260 relations.
# Total 368/1260 relations.
# Total 370/1260 relations.
# Total 371/1260 relations.
# Total 372/1260 relations.
# Total 373/1260 relations.
# Total 374/1260 relations.
# Total 375/1260 relations.
# Total 376/1260 relations.
# Total 377/1260 relations.
# Total 378/1260 relations.
# Total 380/1260 relations.
# Total 381/1260 relations.
# Total 382/1260 relations.
# Total 383/1260 relations.
# Total 384/1260 relations.
# Total 385/1260 relations.
# Total 386/1260 relations.
# Total 387/1260 relations.
# Total 388/1260 relations.
# Total 389/1260 relations.
# Total 390/1260 relations.
# Total 391/1260 relations.
# Total 392/1260 relations.
# Total 393/1260 relations.
# Total 396/1260 relations.
# Total 397/1260 relations.
# Total 399/1260 relations.
# Total 400/1260 relations.
# Total 401/1260 relations.
# Total 402/1260 relations.
# Total 403/1260 relations.
# Total 405/1260 relations.
# Total 406/1260 relations.
# Total 407/1260 relations.
# Total 408/1260 relations.
# Total 409/1260 relations.
# Total 410/1260 relations.
# Total 411/1260 relations.
# Total 412/1260 relations.
# Total 413/1260 relations.
# Total 414/1260 relations.
# Total 415/1260 relations.
# Total 416/1260 relations.
# Total 418/1260 relations.
# Total 419/1260 relations.
# Total 420/1260 relations.
# Total 421/1260 relations.
# Total 422/1260 relations.
# Total 423/1260 relations.
# Total 424/1260 relations.
# Total 425/1260 relations.
# Total 426/1260 relations.
# Total 427/1260 relations.
# Total 428/1260 relations.
# Total 429/1260 relations.
# Total 430/1260 relations.
# Total 431/1260 relations.
# Total 432/1260 relations.
# Total 433/1260 relations.
# Total 434/1260 relations.
# Total 435/1260 relations.
# Total 437/1260 relations.
# Total 438/1260 relations.
# Total 441/1260 relations.
# Total 443/1260 relations.
# Total 444/1260 relations.
# Total 446/1260 relations.
# Total 447/1260 relations.
# Total 448/1260 relations.
# Total 450/1260 relations.
# Total 451/1260 relations.
# Total 452/1260 relations.
# Total 453/1260 relations.
# Total 454/1260 relations.
# Total 455/1260 relations.
# Total 458/1260 relations.
# Total 460/1260 relations.
# Total 462/1260 relations.
# Total 463/1260 relations.
# Total 464/1260 relations.
# Total 465/1260 relations.
# Total 466/1260 relations.
# Total 467/1260 relations.
# Total 468/1260 relations.
# Total 470/1260 relations.
# Total 471/1260 relations.
# Total 473/1260 relations.
# Total 474/1260 relations.
# Total 476/1260 relations.
# Total 477/1260 relations.
# Total 478/1260 relations.
# Total 480/1260 relations.
# Total 482/1260 relations.
# Total 483/1260 relations.
# Total 484/1260 relations.
# Total 485/1260 relations.
# Total 486/1260 relations.
# Total 487/1260 relations.
# Total 488/1260 relations.
# Total 489/1260 relations.
# Total 491/1260 relations.
# Total 492/1260 relations.
# Total 493/1260 relations.
# Total 495/1260 relations.
# Total 496/1260 relations.
# Total 497/1260 relations.
# Total 498/1260 relations.
# Total 499/1260 relations.
# Total 500/1260 relations.
# Total 501/1260 relations.
# Total 502/1260 relations.
# Total 504/1260 relations.
# Total 505/1260 relations.
# Total 506/1260 relations.
# Total 507/1260 relations.
# Total 508/1260 relations.
# Total 509/1260 relations.
# Total 510/1260 relations.
# Total 511/1260 relations.
# Total 512/1260 relations.
# Total 513/1260 relations.
# Total 514/1260 relations.
# Total 515/1260 relations.
# Total 516/1260 relations.
# Total 517/1260 relations.
# Total 518/1260 relations.
# Total 520/1260 relations.
# Total 521/1260 relations.
# Total 523/1260 relations.
# Total 524/1260 relations.
# Total 525/1260 relations.
# Total 526/1260 relations.
# Total 527/1260 relations.
# Total 528/1260 relations.
# Total 529/1260 relations.
# Total 530/1260 relations.
# Total 532/1260 relations.
# Total 534/1260 relations.
# Total 535/1260 relations.
# Total 536/1260 relations.
# Total 537/1260 relations.
# Total 538/1260 relations.
# Total 539/1260 relations.
# Total 541/1260 relations.
# Total 542/1260 relations.
# Total 543/1260 relations.
# Total 544/1260 relations.
# Total 545/1260 relations.
# Total 546/1260 relations.
# Total 547/1260 relations.
# Total 548/1260 relations.
# Total 550/1260 relations.
# Total 551/1260 relations.
# Total 552/1260 relations.
# Total 554/1260 relations.
# Total 555/1260 relations.
# Total 557/1260 relations.
# Total 558/1260 relations.
# Total 559/1260 relations.
# Total 560/1260 relations.
# Total 561/1260 relations.
# Total 562/1260 relations.
# Total 563/1260 relations.
# Total 564/1260 relations.
# Total 565/1260 relations.
# Total 566/1260 relations.
# Total 567/1260 relations.
# Total 569/1260 relations.
# Total 570/1260 relations.
# Total 571/1260 relations.
# Total 572/1260 relations.
# Total 573/1260 relations.
# Total 575/1260 relations.
# Total 577/1260 relations.
# Total 578/1260 relations.
# Total 579/1260 relations.
# Total 580/1260 relations.
# Total 581/1260 relations.
# Total 582/1260 relations.
# Total 583/1260 relations.
# Total 586/1260 relations.
# Total 587/1260 relations.
# Total 588/1260 relations.
# Total 589/1260 relations.
# Total 590/1260 relations.
# Total 591/1260 relations.
# Total 592/1260 relations.
# Total 593/1260 relations.
# Total 594/1260 relations.
# Total 595/1260 relations.
# Total 596/1260 relations.
# Total 597/1260 relations.
# Total 598/1260 relations.
# Total 599/1260 relations.
# Total 601/1260 relations.
# Total 602/1260 relations.
# Total 603/1260 relations.
# Total 604/1260 relations.
# Total 605/1260 relations.
# Total 606/1260 relations.
# Total 608/1260 relations.
# Total 609/1260 relations.
# Total 610/1260 relations.
# Total 611/1260 relations.
# Total 612/1260 relations.
# Total 613/1260 relations.
# Total 614/1260 relations.
# Total 615/1260 relations.
# Total 617/1260 relations.
# Total 618/1260 relations.
# Total 619/1260 relations.
# Total 620/1260 relations.
# Total 621/1260 relations.
# Total 622/1260 relations.
# Total 623/1260 relations.
# Total 625/1260 relations.
# Total 627/1260 relations.
# Total 629/1260 relations.
# Total 630/1260 relations.
# Total 631/1260 relations.
# Total 632/1260 relations.
# Total 634/1260 relations.
# Total 635/1260 relations.
# Total 638/1260 relations.
# Total 640/1260 relations.
# Total 642/1260 relations.
# Total 643/1260 relations.
# Total 645/1260 relations.
# Total 646/1260 relations.
# Total 647/1260 relations.
# Total 648/1260 relations.
# Total 650/1260 relations.
# Total 651/1260 relations.
# Total 653/1260 relations.
# Total 654/1260 relations.
# Total 655/1260 relations.
# Total 656/1260 relations.
# Total 657/1260 relations.
# Total 658/1260 relations.
# Total 659/1260 relations.
# Total 660/1260 relations.
# Total 661/1260 relations.
# Total 662/1260 relations.
# Total 663/1260 relations.
# Total 664/1260 relations.
# Total 665/1260 relations.
# Total 666/1260 relations.
# Total 667/1260 relations.
# Total 668/1260 relations.
# Total 669/1260 relations.
# Total 670/1260 relations.
# Total 671/1260 relations.
# Total 672/1260 relations.
# Total 673/1260 relations.
# Total 674/1260 relations.
# Total 675/1260 relations.
# Total 676/1260 relations.
# Total 677/1260 relations.
# Total 678/1260 relations.
# Total 679/1260 relations.
# Total 680/1260 relations.
# Total 681/1260 relations.
# Total 683/1260 relations.
# Total 684/1260 relations.
# Total 685/1260 relations.
# Total 687/1260 relations.
# Total 689/1260 relations.
# Total 690/1260 relations.
# Total 691/1260 relations.
# Total 693/1260 relations.
# Total 694/1260 relations.
# Total 695/1260 relations.
# Total 696/1260 relations.
# Total 697/1260 relations.
# Total 699/1260 relations.
# Total 701/1260 relations.
# Total 702/1260 relations.
# Total 703/1260 relations.
# Total 704/1260 relations.
# Total 705/1260 relations.
# Total 706/1260 relations.
# Total 707/1260 relations.
# Total 708/1260 relations.
# Total 709/1260 relations.
# Total 711/1260 relations.
# Total 712/1260 relations.
# Total 713/1260 relations.
# Total 715/1260 relations.
# Total 716/1260 relations.
# Total 719/1260 relations.
# Total 720/1260 relations.
# Total 721/1260 relations.
# Total 723/1260 relations.
# Total 724/1260 relations.
# Total 725/1260 relations.
# Total 726/1260 relations.
# Total 727/1260 relations.
# Total 728/1260 relations.
# Total 729/1260 relations.
# Total 730/1260 relations.
# Total 731/1260 relations.
# Total 732/1260 relations.
# Total 733/1260 relations.
# Total 734/1260 relations.
# Total 735/1260 relations.
# Total 736/1260 relations.
# Total 737/1260 relations.
# Total 738/1260 relations.
# Total 740/1260 relations.
# Total 742/1260 relations.
# Total 743/1260 relations.
# Total 744/1260 relations.
# Total 745/1260 relations.
# Total 746/1260 relations.
# Total 748/1260 relations.
# Total 749/1260 relations.
# Total 750/1260 relations.
# Total 751/1260 relations.
# Total 752/1260 relations.
# Total 753/1260 relations.
# Total 754/1260 relations.
# Total 755/1260 relations.
# Total 756/1260 relations.
# Total 757/1260 relations.
# Total 758/1260 relations.
# Total 760/1260 relations.
# Total 761/1260 relations.
# Total 762/1260 relations.
# Total 764/1260 relations.
# Total 765/1260 relations.
# Total 766/1260 relations.
# Total 767/1260 relations.
# Total 768/1260 relations.
# Total 769/1260 relations.
# Total 771/1260 relations.
# Total 774/1260 relations.
# Total 775/1260 relations.
# Total 776/1260 relations.
# Total 778/1260 relations.
# Total 780/1260 relations.
# Total 781/1260 relations.
# Total 782/1260 relations.
# Total 783/1260 relations.
# Total 784/1260 relations.
# Total 785/1260 relations.
# Total 786/1260 relations.
# Total 787/1260 relations.
# Total 789/1260 relations.
# Total 790/1260 relations.
# Total 791/1260 relations.
# Total 792/1260 relations.
# Total 793/1260 relations.
# Total 794/1260 relations.
# Total 796/1260 relations.
# Total 797/1260 relations.
# Total 798/1260 relations.
# Total 799/1260 relations.
# Total 801/1260 relations.
# Total 802/1260 relations.
# Total 803/1260 relations.
# Total 804/1260 relations.
# Total 805/1260 relations.
# Total 806/1260 relations.
# Total 807/1260 relations.
# Total 808/1260 relations.
# Total 809/1260 relations.
# Total 810/1260 relations.
# Total 812/1260 relations.
# Total 813/1260 relations.
# Total 814/1260 relations.
# Total 815/1260 relations.
# Total 816/1260 relations.
# Total 817/1260 relations.
# Total 818/1260 relations.
# Total 819/1260 relations.
# Total 820/1260 relations.
# Total 821/1260 relations.
# Total 822/1260 relations.
# Total 823/1260 relations.
# Total 824/1260 relations.
# Total 825/1260 relations.
# Total 826/1260 relations.
# Total 827/1260 relations.
# Total 829/1260 relations.
# Total 830/1260 relations.
# Total 831/1260 relations.
# Total 832/1260 relations.
# Total 833/1260 relations.
# Total 834/1260 relations.
# Total 835/1260 relations.
# Total 836/1260 relations.
# Total 838/1260 relations.
# Total 839/1260 relations.
# Total 840/1260 relations.
# Total 842/1260 relations.
# Total 843/1260 relations.
# Total 844/1260 relations.
# Total 845/1260 relations.
# Total 846/1260 relations.
# Total 847/1260 relations.
# Total 848/1260 relations.
# Total 849/1260 relations.
# Total 850/1260 relations.
# Total 851/1260 relations.
# Total 852/1260 relations.
# Total 853/1260 relations.
# Total 855/1260 relations.
# Total 856/1260 relations.
# Total 857/1260 relations.
# Total 858/1260 relations.
# Total 859/1260 relations.
# Total 860/1260 relations.
# Total 861/1260 relations.
# Total 862/1260 relations.
# Total 863/1260 relations.
# Total 864/1260 relations.
# Total 865/1260 relations.
# Total 866/1260 relations.
# Total 867/1260 relations.
# Total 868/1260 relations.
# Total 870/1260 relations.
# Total 871/1260 relations.
# Total 872/1260 relations.
# Total 873/1260 relations.
# Total 874/1260 relations.
# Total 875/1260 relations.
# Total 876/1260 relations.
# Total 877/1260 relations.
# Total 879/1260 relations.
# Total 881/1260 relations.
# Total 883/1260 relations.
# Total 884/1260 relations.
# Total 885/1260 relations.
# Total 886/1260 relations.
# Total 887/1260 relations.
# Total 888/1260 relations.
# Total 889/1260 relations.
# Total 890/1260 relations.
# Total 892/1260 relations.
# Total 893/1260 relations.
# Total 894/1260 relations.
# Total 895/1260 relations.
# Total 897/1260 relations.
# Total 898/1260 relations.
# Total 902/1260 relations.
# Total 903/1260 relations.
# Total 904/1260 relations.
# Total 905/1260 relations.
# Total 906/1260 relations.
# Total 907/1260 relations.
# Total 908/1260 relations.
# Total 909/1260 relations.
# Total 910/1260 relations.
# Total 911/1260 relations.
# Total 913/1260 relations.
# Total 914/1260 relations.
# Total 915/1260 relations.
# Total 916/1260 relations.
# Total 917/1260 relations.
# Total 919/1260 relations.
# Total 920/1260 relations.
# Total 921/1260 relations.
# Total 922/1260 relations.
# Total 923/1260 relations.
# Total 924/1260 relations.
# Total 925/1260 relations.
# Total 926/1260 relations.
# Total 927/1260 relations.
# Total 929/1260 relations.
# Total 931/1260 relations.
# Total 933/1260 relations.
# Total 934/1260 relations.
# Total 935/1260 relations.
# Total 936/1260 relations.
# Total 937/1260 relations.
# Total 938/1260 relations.
# Total 939/1260 relations.
# Total 940/1260 relations.
# Total 941/1260 relations.
# Total 942/1260 relations.
# Total 943/1260 relations.
# Total 944/1260 relations.
# Total 946/1260 relations.
# Total 947/1260 relations.
# Total 948/1260 relations.
# Total 949/1260 relations.
# Total 950/1260 relations.
# Total 951/1260 relations.
# Total 953/1260 relations.
# Total 954/1260 relations.
# Total 955/1260 relations.
# Total 956/1260 relations.
# Total 958/1260 relations.
# Total 959/1260 relations.
# Total 960/1260 relations.
# Total 961/1260 relations.
# Total 962/1260 relations.
# Total 963/1260 relations.
# Total 964/1260 relations.
# Total 968/1260 relations.
# Total 969/1260 relations.
# Total 970/1260 relations.
# Total 971/1260 relations.
# Total 972/1260 relations.
# Total 974/1260 relations.
# Total 975/1260 relations.
# Total 976/1260 relations.
# Total 977/1260 relations.
# Total 978/1260 relations.
# Total 979/1260 relations.
# Total 980/1260 relations.
# Total 981/1260 relations.
# Total 982/1260 relations.
# Total 983/1260 relations.
# Total 984/1260 relations.
# Total 985/1260 relations.
# Total 986/1260 relations.
# Total 987/1260 relations.
# Total 988/1260 relations.
# Total 990/1260 relations.
# Total 991/1260 relations.
# Total 992/1260 relations.
# Total 993/1260 relations.
# Total 994/1260 relations.
# Total 995/1260 relations.
# Total 996/1260 relations.
# Total 997/1260 relations.
# Total 998/1260 relations.
# Total 999/1260 relations.
# Total 1000/1260 relations.
# Total 1001/1260 relations.
# Total 1005/1260 relations.
# Total 1006/1260 relations.
# Total 1007/1260 relations.
# Total 1008/1260 relations.
# Total 1009/1260 relations.
# Total 1010/1260 relations.
# Total 1011/1260 relations.
# Total 1012/1260 relations.
# Total 1014/1260 relations.
# Total 1015/1260 relations.
# Total 1016/1260 relations.
# Total 1017/1260 relations.
# Total 1018/1260 relations.
# Total 1019/1260 relations.
# Total 1020/1260 relations.
# Total 1021/1260 relations.
# Total 1022/1260 relations.
# Total 1023/1260 relations.
# Total 1024/1260 relations.
# Total 1025/1260 relations.
# Total 1026/1260 relations.
# Total 1027/1260 relations.
# Total 1028/1260 relations.
# Total 1030/1260 relations.
# Total 1032/1260 relations.
# Total 1033/1260 relations.
# Total 1034/1260 relations.
# Total 1035/1260 relations.
# Total 1037/1260 relations.
# Total 1038/1260 relations.
# Total 1039/1260 relations.
# Total 1040/1260 relations.
# Total 1041/1260 relations.
# Total 1042/1260 relations.
# Total 1043/1260 relations.
# Total 1044/1260 relations.
# Total 1045/1260 relations.
# Total 1046/1260 relations.
# Total 1048/1260 relations.
# Total 1049/1260 relations.
# Total 1050/1260 relations.
# Total 1051/1260 relations.
# Total 1052/1260 relations.
# Total 1053/1260 relations.
# Total 1054/1260 relations.
# Total 1055/1260 relations.
# Total 1056/1260 relations.
# Total 1057/1260 relations.
# Total 1058/1260 relations.
# Total 1060/1260 relations.
# Total 1061/1260 relations.
# Total 1063/1260 relations.
# Total 1064/1260 relations.
# Total 1065/1260 relations.
# Total 1067/1260 relations.
# Total 1068/1260 relations.
# Total 1070/1260 relations.
# Total 1071/1260 relations.
# Total 1072/1260 relations.
# Total 1073/1260 relations.
# Total 1074/1260 relations.
# Total 1076/1260 relations.
# Total 1077/1260 relations.
# Total 1079/1260 relations.
# Total 1080/1260 relations.
# Total 1081/1260 relations.
# Total 1082/1260 relations.
# Total 1083/1260 relations.
# Total 1084/1260 relations.
# Total 1085/1260 relations.
# Total 1086/1260 relations.
# Total 1087/1260 relations.
# Total 1088/1260 relations.
# Total 1089/1260 relations.
# Total 1091/1260 relations.
# Total 1092/1260 relations.
# Total 1093/1260 relations.
# Total 1094/1260 relations.
# Total 1095/1260 relations.
# Total 1096/1260 relations.
# Total 1097/1260 relations.
# Total 1099/1260 relations.
# Total 1100/1260 relations.
# Total 1101/1260 relations.
# Total 1102/1260 relations.
# Total 1103/1260 relations.
# Total 1104/1260 relations.
# Total 1105/1260 relations.
# Total 1106/1260 relations.
# Total 1107/1260 relations.
# Total 1108/1260 relations.
# Total 1110/1260 relations.
# Total 1112/1260 relations.
# Total 1114/1260 relations.
# Total 1115/1260 relations.
# Total 1116/1260 relations.
# Total 1119/1260 relations.
# Total 1120/1260 relations.
# Total 1121/1260 relations.
# Total 1122/1260 relations.
# Total 1125/1260 relations.
# Total 1126/1260 relations.
# Total 1127/1260 relations.
# Total 1128/1260 relations.
# Total 1129/1260 relations.
# Total 1130/1260 relations.
# Total 1131/1260 relations.
# Total 1132/1260 relations.
# Total 1133/1260 relations.
# Total 1134/1260 relations.
# Total 1136/1260 relations.
# Total 1138/1260 relations.
# Total 1139/1260 relations.
# Total 1140/1260 relations.
# Total 1141/1260 relations.
# Total 1143/1260 relations.
# Total 1144/1260 relations.
# Total 1145/1260 relations.
# Total 1146/1260 relations.
# Total 1147/1260 relations.
# Total 1148/1260 relations.
# Total 1149/1260 relations.
# Total 1150/1260 relations.
# Total 1151/1260 relations.
# Total 1152/1260 relations.
# Total 1153/1260 relations.
# Total 1154/1260 relations.
# Total 1155/1260 relations.
# Total 1156/1260 relations.
# Total 1157/1260 relations.
# Total 1158/1260 relations.
# Total 1159/1260 relations.
# Total 1160/1260 relations.
# Total 1162/1260 relations.
# Total 1163/1260 relations.
# Total 1165/1260 relations.
# Total 1166/1260 relations.
# Total 1168/1260 relations.
# Total 1169/1260 relations.
# Total 1170/1260 relations.
# Total 1171/1260 relations.
# Total 1172/1260 relations.
# Total 1173/1260 relations.
# Total 1174/1260 relations.
# Total 1175/1260 relations.
# Total 1176/1260 relations.
# Total 1177/1260 relations.
# Total 1178/1260 relations.
# Total 1179/1260 relations.
# Total 1180/1260 relations.
# Total 1181/1260 relations.
# Total 1182/1260 relations.
# Total 1183/1260 relations.
# Total 1185/1260 relations.
# Total 1186/1260 relations.
# Total 1187/1260 relations.
# Total 1188/1260 relations.
# Total 1189/1260 relations.
# Total 1190/1260 relations.
# Total 1191/1260 relations.
# Total 1192/1260 relations.
# Total 1193/1260 relations.
# Total 1195/1260 relations.
# Total 1196/1260 relations.
# Total 1197/1260 relations.
# Total 1199/1260 relations.
# Total 1200/1260 relations.
# Total 1201/1260 relations.
# Total 1203/1260 relations.
# Total 1205/1260 relations.
# Total 1206/1260 relations.
# Total 1207/1260 relations.
# Total 1208/1260 relations.
# Total 1209/1260 relations.
# Total 1210/1260 relations.
# Total 1212/1260 relations.
# Total 1213/1260 relations.
# Total 1215/1260 relations.
# Total 1218/1260 relations.
# Total 1219/1260 relations.
# Total 1220/1260 relations.
# Total 1222/1260 relations.
# Total 1223/1260 relations.
# Total 1224/1260 relations.
# Total 1226/1260 relations.
# Total 1227/1260 relations.
# Total 1228/1260 relations.
# Total 1230/1260 relations.
# Total 1231/1260 relations.
# Total 1232/1260 relations.
# Total 1233/1260 relations.
# Total 1234/1260 relations.
# Total 1236/1260 relations.
# Total 1237/1260 relations.
# Total 1239/1260 relations.
# Total 1240/1260 relations.
# Total 1242/1260 relations.
# Total 1243/1260 relations.
# Total 1244/1260 relations.
# Total 1245/1260 relations.
# Total 1247/1260 relations.
# Total 1249/1260 relations.
# Total 1251/1260 relations.
# Total 1252/1260 relations.
# Total 1253/1260 relations.
# Total 1254/1260 relations.
# Total 1255/1260 relations.
# Total 1256/1260 relations.
# Total 1257/1260 relations.
# Total 1258/1260 relations.
# Total 1259/1260 relations.
# Total 1260/1260 relations.
# *** Step 2/2: Linear Algebra ***
# Building matrix for linear algebra step...
# Finding perfect squares using matrix...
# Finding factors from perfect squares...
# SIQS: Prime factor found: 1123456667890987666543211
# Prime factor found: 1123456667890987666543211
# Prime factor found: 3333322225555555777777777
#
# Success. Prime factors: [1123456667890987666543211, 3333322225555555777777777]
# Factorising 6172835808641975203638304919691358469663 (40 digits)...
# Trial division and initialising small primes...
# Primes initialised.
# No small factors found.
# Attempting quick Pollard rho (Brent's variant) to find slightly larger factors...
# No (more) small factors found.
# Checking whether 6172835808641975203638304919691358469663 is a perfect power...
# Not a perfect power.
# Using Self-Initializing Quadratic Sieve to factorise 6172835808641975203638304919691358469663 (40 digits)...
# *** Step 1/2: Finding smooth relations ***
# Target: 525 relations
# Total 2/525 relations.
# Total 4/525 relations.
# Total 7/525 relations.
# Total 10/525 relations.
# Total 11/525 relations.
# Total 13/525 relations.
# Total 16/525 relations.
# Total 17/525 relations.
# Total 19/525 relations.
# Total 20/525 relations.
# Total 21/525 relations.
# Total 26/525 relations.
# Total 30/525 relations.
# Total 34/525 relations.
# Total 37/525 relations.
# Total 40/525 relations.
# Total 43/525 relations.
# Total 45/525 relations.
# Total 46/525 relations.
# Total 48/525 relations.
# Total 50/525 relations.
# Total 52/525 relations.
# Total 54/525 relations.
# Total 56/525 relations.
# Total 59/525 relations.
# Total 62/525 relations.
# Total 67/525 relations.
# Total 70/525 relations.
# Total 72/525 relations.
# Total 73/525 relations.
# Total 75/525 relations.
# Total 78/525 relations.
# Total 80/525 relations.
# Total 82/525 relations.
# Total 83/525 relations.
# Total 85/525 relations.
# Total 87/525 relations.
# Total 89/525 relations.
# Total 91/525 relations.
# Total 92/525 relations.
# Total 93/525 relations.
# Total 95/525 relations.
# Total 97/525 relations.
# Total 101/525 relations.
# Total 102/525 relations.
# Total 103/525 relations.
# Total 105/525 relations.
# Total 106/525 relations.
# Total 107/525 relations.
# Total 110/525 relations.
# Total 113/525 relations.
# Total 115/525 relations.
# Total 116/525 relations.
# Total 119/525 relations.
# Total 121/525 relations.
# Total 124/525 relations.
# Total 127/525 relations.
# Total 128/525 relations.
# Total 129/525 relations.
# Total 133/525 relations.
# Total 134/525 relations.
# Total 136/525 relations.
# Total 138/525 relations.
# Total 139/525 relations.
# Total 140/525 relations.
# Total 141/525 relations.
# Total 142/525 relations.
# Total 143/525 relations.
# Total 144/525 relations.
# Total 145/525 relations.
# Total 147/525 relations.
# Total 151/525 relations.
# Total 152/525 relations.
# Total 153/525 relations.
# Total 154/525 relations.
# Total 156/525 relations.
# Total 157/525 relations.
# Total 159/525 relations.
# Total 161/525 relations.
# Total 162/525 relations.
# Total 163/525 relations.
# Total 165/525 relations.
# Total 167/525 relations.
# Total 168/525 relations.
# Total 169/525 relations.
# Total 173/525 relations.
# Total 175/525 relations.
# Total 176/525 relations.
# Total 178/525 relations.
# Total 180/525 relations.
# Total 181/525 relations.
# Total 183/525 relations.
# Total 187/525 relations.
# Total 190/525 relations.
# Total 192/525 relations.
# Total 193/525 relations.
# Total 196/525 relations.
# Total 198/525 relations.
# Total 200/525 relations.
# Total 201/525 relations.
# Total 205/525 relations.
# Total 206/525 relations.
# Total 207/525 relations.
# Total 211/525 relations.
# Total 213/525 relations.
# Total 214/525 relations.
# Total 216/525 relations.
# Total 218/525 relations.
# Total 220/525 relations.
# Total 221/525 relations.
# Total 224/525 relations.
# Total 225/525 relations.
# Total 228/525 relations.
# Total 229/525 relations.
# Total 231/525 relations.
# Total 234/525 relations.
# Total 237/525 relations.
# Total 239/525 relations.
# Total 240/525 relations.
# Total 241/525 relations.
# Total 245/525 relations.
# Total 246/525 relations.
# Total 248/525 relations.
# Total 251/525 relations.
# Total 252/525 relations.
# Total 255/525 relations.
# Total 258/525 relations.
# Total 259/525 relations.
# Total 262/525 relations.
# Total 264/525 relations.
# Total 268/525 relations.
# Total 269/525 relations.
# Total 271/525 relations.
# Total 273/525 relations.
# Total 275/525 relations.
# Total 277/525 relations.
# Total 279/525 relations.
# Total 283/525 relations.
# Total 285/525 relations.
# Total 288/525 relations.
# Total 291/525 relations.
# Total 294/525 relations.
# Total 296/525 relations.
# Total 298/525 relations.
# Total 302/525 relations.
# Total 306/525 relations.
# Total 309/525 relations.
# Total 310/525 relations.
# Total 312/525 relations.
# Total 316/525 relations.
# Total 321/525 relations.
# Total 324/525 relations.
# Total 325/525 relations.
# Total 326/525 relations.
# Total 330/525 relations.
# Total 332/525 relations.
# Total 334/525 relations.
# Total 338/525 relations.
# Total 340/525 relations.
# Total 343/525 relations.
# Total 344/525 relations.
# Total 345/525 relations.
# Total 348/525 relations.
# Total 352/525 relations.
# Total 357/525 relations.
# Total 361/525 relations.
# Total 364/525 relations.
# Total 365/525 relations.
# Total 368/525 relations.
# Total 369/525 relations.
# Total 377/525 relations.
# Total 379/525 relations.
# Total 381/525 relations.
# Total 385/525 relations.
# Total 387/525 relations.
# Total 388/525 relations.
# Total 390/525 relations.
# Total 392/525 relations.
# Total 393/525 relations.
# Total 397/525 relations.
# Total 398/525 relations.
# Total 402/525 relations.
# Total 403/525 relations.
# Total 405/525 relations.
# Total 407/525 relations.
# Total 411/525 relations.
# Total 415/525 relations.
# Total 416/525 relations.
# Total 423/525 relations.
# Total 426/525 relations.
# Total 427/525 relations.
# Total 430/525 relations.
# Total 433/525 relations.
# Total 436/525 relations.
# Total 437/525 relations.
# Total 438/525 relations.
# Total 441/525 relations.
# Total 445/525 relations.
# Total 448/525 relations.
# Total 449/525 relations.
# Total 453/525 relations.
# Total 454/525 relations.
# Total 456/525 relations.
# Total 458/525 relations.
# Total 460/525 relations.
# Total 462/525 relations.
# Total 465/525 relations.
# Total 466/525 relations.
# Total 468/525 relations.
# Total 469/525 relations.
# Total 470/525 relations.
# Total 471/525 relations.
# Total 473/525 relations.
# Total 474/525 relations.
# Total 475/525 relations.
# Total 478/525 relations.
# Total 480/525 relations.
# Total 482/525 relations.
# Total 483/525 relations.
# Total 486/525 relations.
# Total 488/525 relations.
# Total 489/525 relations.
# Total 492/525 relations.
# Total 497/525 relations.
# Total 503/525 relations.
# Total 505/525 relations.
# Total 509/525 relations.
# Total 511/525 relations.
# Total 512/525 relations.
# Total 513/525 relations.
# Total 517/525 relations.
# Total 519/525 relations.
# Total 522/525 relations.
# Total 525/525 relations.
# *** Step 2/2: Linear Algebra ***
# Building matrix for linear algebra step...
# Finding perfect squares using matrix...
# Finding factors from perfect squares...
# SIQS: Prime factor found: 11111111111111111011
# Prime factor found: 555555222777777773333
# Prime factor found: 11111111111111111011
#
# Success. Prime factors: [11111111111111111011, 555555222777777773333]
# Factorising 46839566299936919234246726809 (29 digits)...
# Trial division and initialising small primes...
# Primes initialised.
# No small factors found.
# Checking whether 46839566299936919234246726809 is a perfect power...
# Not a perfect power.
# Using Pollard rho (Brent's variant) to factorise 46839566299936919234246726809 (29 digits)...
# Prime factor found: 100000000105583
#
# Success. Prime factors: [100000000105583, 468395662504823]
